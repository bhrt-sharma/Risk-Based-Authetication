# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
df = pd.read_csv("data/RBA.csv")

# %%
df.head(5)
# Out:
#    idvisit  idsite idvisitor visit_last_action_time  config_id location_ip  \
# 0       23       2  S���
# ;       26-06-2019 12:18    HŘ}��C          �4
# 1       47       2  ��f�Z�S       26-06-2019 12:18  +��5L�\n          �]
# 2       48       2  ��f�Z�S       26-06-2019 02:19   D��C���          �v
# 3       49       2  ��f�Z�S       26-06-2019 02:50    �-;Q�Z          H�
# 4       50       2  ��f�Z�S       26-06-2019 03:38   �a:,��x          ��
#
#     user_id visit_first_action_time  visit_goal_buyer  visit_goal_converted  \
# 0  Gretchen        26-06-2019 12:18                 0                     0
# 1  Johathan        26-06-2019 12:18                 2                     0
# 2  Johathan        26-06-2019 01:54                 0                     0
# 3  Johathan        26-06-2019 02:50                 0                     0
# 4  Johathan        26-06-2019 03:38                 0                     0
#
# ...

# %%
df.columns
# Out:
# Index(['idvisit', 'idsite', 'idvisitor', 'visit_last_action_time', 'config_id',
#        'location_ip', 'user_id', 'visit_first_action_time', 'visit_goal_buyer',
#        'visit_goal_converted', 'visitor_days_since_first',
#        'visitor_days_since_order', 'visitor_returning', 'visitor_count_visits',
#        'visit_entry_idaction_name', 'visit_entry_idaction_url',
#        'visit_exit_idaction_name', 'visit_exit_idaction_url',
#        'visit_total_actions', 'visit_total_interactions',
#        'visit_total_searches', 'referer_keyword', 'referer_name',
#        'referer_type', 'referer_url', 'location_browser_lang',
#        'config_browser_engine', 'config_browser_name',
#        'config_browser_version', 'config_device_brand', 'config_device_model',
#        'config_device_type', 'config_os', 'config_os_version',
#        'visit_total_events', 'visitor_localtime', 'visitor_days_since_last',
#        'config_resolution', 'config_cookie', 'config_director', 'config_flash',
# ...

# %%
drop = ["location_ip",'idvisitor','config_id',"custom_var_v1","custom_var_k2"]

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
df['user_id']= label_encoder.fit_transform(df['user_id']) 
  
df['user_id'].unique()
# Out:
# array([25, 31, 45,  9, 55, 20,  2, 34, 17, 40, 46, 33, 21,  5, 29, 15, 35,
#        26, 23, 24,  6, 11, 50, 22,  7, 43, 42, 19, 49,  4, 30, 54, 28, 10,
#        13, 14, 16, 48, 27, 51, 36, 37,  0, 52,  1, 38, 32, 41, 47, 53, 44,
#         3, 18, 39,  8, 56, 12])

# %%
df.columns
# Out:
# Index(['idvisit', 'idsite', 'idvisitor', 'visit_last_action_time', 'config_id',
#        'location_ip', 'user_id', 'visit_first_action_time', 'visit_goal_buyer',
#        'visit_goal_converted', 'visitor_days_since_first',
#        'visitor_days_since_order', 'visitor_returning', 'visitor_count_visits',
#        'visit_entry_idaction_name', 'visit_entry_idaction_url',
#        'visit_exit_idaction_name', 'visit_exit_idaction_url',
#        'visit_total_actions', 'visit_total_interactions',
#        'visit_total_searches', 'referer_keyword', 'referer_name',
#        'referer_type', 'referer_url', 'location_browser_lang',
#        'config_browser_engine', 'config_browser_name',
#        'config_browser_version', 'config_device_brand', 'config_device_model',
#        'config_device_type', 'config_os', 'config_os_version',
#        'visit_total_events', 'visitor_localtime', 'visitor_days_since_last',
#        'config_resolution', 'config_cookie', 'config_director', 'config_flash',
# ...

# %%
df['config_webgl'].unique()
# Out:
# array([  0.,  nan])

# %%
df['config_webgl'].value_counts()
# Out:
# 0.0    231
# Name: config_webgl, dtype: int64

# %%
drop = ["location_ip",'idvisitor','config_id',"custom_var_v1","custom_var_k2","visit_goal_buyer","visitor_days_since_first","referer_url","config_device_type","visitor_days_since_last","custom_var_k1","custom_var_k2","custom_var_k4","custom_var_k3","custom_var_v4", 'custom_var_k5', 'custom_var_v5','config_webgl']

# %%
df['referer_name'].value_counts()
# Out:
# Facebook                     32
# Google                       31
# Twitter                      23
# Bing                         21
# email-nov2011                21
# www.example.org              20
# blog                         19
# Yahoo!                       18
# Ask                          12
# Yandex                       10
# GitHub                        8
# \N                            7
# www.example.com               7
# DuckDuckGo                    6
# Yahoo! Japan                  5
# heathcote.com                 2
# www.carter.com                2
# herzog.com                    2
# www.towne.com                 2
# www.berniermorissette.com     2
# dachmayert.com                2
# www.nader.net                 2
# parker.biz                    2
# okuneva.com                   2
# www.vonrueden.net             2
# lebsack.com                   2
# ziemebins.com                 2
# www.ortizwintheiser.com       2
# www.hammes.biz                2
# ...

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['referer_name']= label_encoder.fit_transform(df['referer_name'].fillna('0')) 
  
df['referer_name'].unique()
# Out:
# array([ 5,  7,  8, 68, 26, 75,  0, 31,  3,  2, 47, 74, 35,  9, 20, 10,  4,
#        53, 78, 34, 67, 27, 18, 54, 15, 29, 11, 59, 43, 24, 45,  6, 36, 25,
#        44, 56, 51, 46, 40, 19, 50, 38, 76, 23, 28, 69, 33, 72, 14, 49, 32,
#        71, 62, 37, 41, 64, 57, 63, 66, 60, 55, 65, 12, 16, 52, 21, 30,  1,
#        39, 61, 77, 70, 48, 73, 17, 42, 13, 22, 58])

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['referer_keyword']= label_encoder.fit_transform(df['referer_keyword'].fillna('0')) 
  
df['referer_keyword'].unique()
# Out:
# array([ 0, 39, 29, 20,  8, 24, 37, 15, 28, 47, 33,  5, 36, 42, 10, 35, 44,
#        26, 23, 45, 32, 19, 12, 30,  9, 46, 22,  7, 40, 27, 13,  2, 16,  1,
#        38, 31, 11, 21,  3, 18, 34,  6, 14, 17, 25, 41, 43,  4])

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['referer_type']= label_encoder.fit_transform(df['referer_type'].fillna('0')) 
  
df['referer_type'].unique()
# Out:
# array([4, 1, 2, 0, 3, 5])

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['location_browser_lang']= label_encoder.fit_transform(df['location_browser_lang'].fillna('0')) 
  
df['location_browser_lang'].unique()
# Out:
# array([82, 42, 18, 84, 32,  6, 23, 29,  3, 73, 56, 53, 50, 63, 19, 15, 43,
#        26, 24, 67, 60, 38, 66, 47, 74, 62, 80,  9, 52, 35,  8,  4, 58, 12,
#        40, 48, 37, 55, 21, 16, 51, 33,  0, 17,  2, 45, 83, 57,  7, 70, 61,
#        28, 81, 39, 41, 85, 69, 54, 30, 13, 75, 64, 68, 14, 76, 27, 65, 22,
#        78, 10, 79, 72, 49,  1, 20, 44, 59, 36, 11, 25, 46, 77, 31, 71,  5,
#        34])

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['config_browser_engine']= label_encoder.fit_transform(df['config_browser_engine'].fillna('0')) 
  
df['config_browser_engine'].unique()
# Out:
# array([5, 3, 1, 4, 0, 2])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['config_browser_name']= label_encoder.fit_transform(df['config_browser_name'].fillna('0')) 
  
df['config_browser_name'].unique()
# Out:
# array([6, 5, 2, 3, 4, 1, 7, 0])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['config_device_brand']= label_encoder.fit_transform(df['config_device_brand'].fillna('0')) 
  
df['config_device_brand'].unique()
# Out:
# array([0, 1, 2])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['config_device_model']= label_encoder.fit_transform(df['config_device_model'].fillna('0')) 
  
df['config_device_model'].unique()
# Out:
# array([1, 3, 2, 0])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['config_os']= label_encoder.fit_transform(df['config_os'].fillna('0')) 
  
df['config_os'].unique()
# Out:
# array([6, 1, 2, 0, 5, 4, 3])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['config_os_version']= label_encoder.fit_transform(df['config_os_version'].fillna('0')) 
  
df['config_os_version'].unique()
# Out:
# array([22,  0,  1, 18, 11,  5,  8, 15, 20,  3, 23, 16,  4, 12, 19, 14,  2,
#        13,  7,  9,  6, 21, 17, 10])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['visit_total_events']= label_encoder.fit_transform(df['visit_total_events'].fillna('0')) 
  
df['visit_total_events'].unique()
# Out:
# array([0, 5, 4, 6, 3, 1, 7, 2, 8])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['config_resolution']= label_encoder.fit_transform(df['config_resolution'].fillna('0')) 
  
df['config_resolution'].unique()
# Out:
# array([13,  8, 14, 15,  2,  4, 10, 21,  1, 22, 12,  7,  5, 16, 25, 17, 23,
#         9, 19, 18, 20, 11,  6,  3, 24,  0])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['config_cookie']= label_encoder.fit_transform(df['config_cookie'].fillna('0')) 
  
df['config_cookie'].unique()
# Out:
# array([1, 0])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['visit_total_time']= label_encoder.fit_transform(df['visit_total_time'].fillna('0')) 
  
df['visit_total_time'].unique()
# Out:
# array([ 0,  1,  6,  3, 11, 15,  8, 23, 21,  5,  4, 20, 22, 17, 16,  9, 10,
#        19, 12,  2, 13, 25, 18, 14,  7, 24])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['location_city']= label_encoder.fit_transform(df['location_city'].fillna('1000')) 
  
df['location_city'].unique()
# Out:
# array([108, 148, 195, 113, 145, 125,  86,  66, 219,  98, 248,  70, 192,
#        205,  43, 214, 208, 266,  59,  42, 218, 177, 255, 103, 119, 207,
#        109,  26, 243,  18,  28,  71,  88, 193, 161, 245, 201,  10, 118,
#        133,   8, 146,   0, 117,  57, 215,  32, 187,  12,  80, 159,  96,
#        170,  63, 142, 180, 105,  50, 257, 235, 164, 160,  78, 165, 129,
#        114,  48,  91, 112,  31, 132,  36, 211,   7,  51, 181, 104,  23,
#        210, 202,  76, 264,  24, 230, 139, 203,  49, 131, 265,   6,  29,
#         16, 151, 168, 231, 128, 149,  68,  64,  58, 156,  82, 126, 102,
#        227,  34,  95, 260, 216,  69, 162, 176, 217, 186, 251, 188, 111,
#        173, 183,   2, 101, 182, 226, 220, 163, 224,  73, 228,  74,  85,
#         93, 179,  56, 122, 199, 155, 178,  30, 196,  99,  47,  25, 221,
#         60, 229, 234, 197, 239, 158, 241, 174, 249,  89, 263,  35,  46,
#        223,  37,  54, 185, 246, 143, 184, 212, 100,  33,  92, 190, 144,
# ...

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['location_country']= label_encoder.fit_transform(df['location_country'].fillna('1000')) 
  
df['location_country'].unique()
# Out:
# array([ 8, 11,  2,  3,  7,  9,  6,  4,  5, 13,  1, 10, 12,  0])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['custom_var_v1']= label_encoder.fit_transform(df['custom_var_v1'].fillna('1000')) 
  
df['custom_var_v1'].unique()
# Out:
# array([3, 4, 0, 2, 1])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['custom_var_v2']= label_encoder.fit_transform(df['custom_var_v2'].fillna('1000')) 
  
df['custom_var_v2'].unique()
# Out:
# array([ 3,  5,  0,  9,  4, 10,  6,  8,  1,  7,  2, 12, 11])

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['custom_var_v3']= label_encoder.fit_transform(df['custom_var_v3'].fillna('1000')) 
  
df['custom_var_v3'].unique()
# Out:
# array([4, 6, 8, 7, 9, 2, 5, 3, 0, 1])

# %%
df = df.drop(drop,axis=1)

# %%
df.columns
# Out:
# Index(['idvisit', 'idsite', 'visit_last_action_time', 'user_id',
#        'visit_first_action_time', 'visit_goal_converted',
#        'visitor_days_since_order', 'visitor_returning', 'visitor_count_visits',
#        'visit_entry_idaction_name', 'visit_entry_idaction_url',
#        'visit_exit_idaction_name', 'visit_exit_idaction_url',
#        'visit_total_actions', 'visit_total_interactions',
#        'visit_total_searches', 'referer_keyword', 'referer_name',
#        'referer_type', 'location_browser_lang', 'config_browser_engine',
#        'config_browser_name', 'config_browser_version', 'config_device_brand',
#        'config_device_model', 'config_os', 'config_os_version',
#        'visit_total_events', 'visitor_localtime', 'config_resolution',
#        'config_cookie', 'config_director', 'config_flash', 'config_gears',
#        'config_java', 'config_pdf', 'config_quicktime', 'config_realplayer',
#        'config_silverlight', 'config_windowsmedia', 'visit_total_time',
# ...

# %%
df.head()
# Out:
#    idvisit  idsite visit_last_action_time  user_id visit_first_action_time  \
# 0       23       2       26-06-2019 12:18       25        26-06-2019 12:18
# 1       47       2       26-06-2019 12:18       31        26-06-2019 12:18
# 2       48       2       26-06-2019 02:19       31        26-06-2019 01:54
# 3       49       2       26-06-2019 02:50       31        26-06-2019 02:50
# 4       50       2       26-06-2019 03:38       31        26-06-2019 03:38
#
#    visit_goal_converted  visitor_days_since_order  visitor_returning  \
# 0                     0                         0                  2
# 1                     0                         0                  0
# 2                     0                         0                  0
# 3                     0                         0                  1
# 4                     0                         0                  1
#
#    visitor_count_visits  visit_entry_idaction_name visit_entry_idaction_url  \
# ...

# %%
df.describe()
# Out:
#            idvisit      idsite     user_id  visit_goal_converted  \
# count   345.000000  345.000000  345.000000            345.000000
# mean    484.330435    1.669565   29.513043              0.075362
# std     473.499000    0.471053   16.129580              0.264358
# min      23.000000    1.000000    0.000000              0.000000
# 25%     119.000000    1.000000   17.000000              0.000000
# 50%     215.000000    2.000000   31.000000              0.000000
# 75%    1092.000000    2.000000   42.000000              0.000000
# max    1260.000000    2.000000   56.000000              1.000000
#
#        visitor_days_since_order  visitor_returning  visitor_count_visits  \
# count                345.000000         345.000000            345.000000
# mean                   0.002899           0.892754              4.608696
# std                    0.053838           0.653772             62.278542
# min                    0.000000           0.000000              1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 48 columns):
# idvisit                      345 non-null int64
# idsite                       345 non-null int64
# visit_last_action_time       345 non-null object
# user_id                      345 non-null int64
# visit_first_action_time      345 non-null object
# visit_goal_converted         345 non-null int64
# visitor_days_since_order     345 non-null int64
# visitor_returning            345 non-null int64
# visitor_count_visits         345 non-null int64
# visit_entry_idaction_name    345 non-null int64
# visit_entry_idaction_url     312 non-null object
# visit_exit_idaction_name     345 non-null int64
# visit_exit_idaction_url      340 non-null object
# visit_total_actions          345 non-null int64
# visit_total_interactions     345 non-null int64
# visit_total_searches         345 non-null object
# referer_keyword              345 non-null int64
# ...

# %%
df1 = df['location_latitude']
df2 = df['location_longitude']
data = pd.concat([df1, df2], axis=1)
df1 = df1.astype(str)+" " + df2.astype(str)

# %%
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df1= label_encoder.fit_transform(df1) 
  
df1
# Out:
# array([118, 239, 190,  75,  60, 104,  23, 115,  43,  31, 243, 240, 109,
#         84, 251, 210,  11, 160, 247, 266, 143, 235, 193,  65, 212, 176,
#         50,  41, 186,   5, 170, 132, 173, 155,  59, 258,  25, 245,  72,
#        168,  95,  14,  87, 208, 121,  96, 161, 265,  88, 194, 100,  99,
#         51, 204,  71, 185, 257, 209,  98, 119,  39,  29,  70, 255, 105,
#         12,  28,  90, 133, 118, 239, 190,  75,  60, 104,  23, 115,  43,
#         31, 243, 240, 109,  84, 251, 210,  11, 160, 247, 266, 143, 235,
#        193,  65, 212, 176,  50,  41, 186,   5, 170, 132, 173, 155,  59,
#        258,  25, 245,  72, 168,  95,  14,  87, 208, 121,  96, 161, 265,
#         88, 194, 100,  99,  51, 204,  71, 185, 257, 209,  98, 119,  39,
#         29,  70, 255, 105,  12,  28,  90, 133, 182, 157,   4,  61,  27,
#        156,   8,  63,  93,  40, 116, 177,  79,   0, 154, 111, 111, 199,
#        147, 178, 114, 229, 171, 192, 250, 237, 207, 102, 218, 202,  81,
# ...

# %%
pd.options.display.max_columns = 100

# %%
df.head()
# Out:
#    idvisit  idsite visit_last_action_time  user_id visit_first_action_time  \
# 0       23       2       26-06-2019 12:18       25        26-06-2019 12:18
# 1       47       2       26-06-2019 12:18       31        26-06-2019 12:18
# 2       48       2       26-06-2019 02:19       31        26-06-2019 01:54
# 3       49       2       26-06-2019 02:50       31        26-06-2019 02:50
# 4       50       2       26-06-2019 03:38       31        26-06-2019 03:38
#
#    visit_goal_converted  visitor_days_since_order  visitor_returning  \
# 0                     0                         0                  2
# 1                     0                         0                  0
# 2                     0                         0                  0
# 3                     0                         0                  1
# 4                     0                         0                  1
#
#    visitor_count_visits  visit_entry_idaction_name visit_entry_idaction_url  \
# ...

# %%
df.shape
# Out:
# (345, 48)

# %%
df1 = pd.DataFrame(df1)

# %%
df1.columns = ['longlat']

# %% [markdown]
# #

# %%
df =  pd.concat([df,df1], axis = 1)

# %%
df.columns
# Out:
# Index(['idvisit', 'idsite', 'visit_last_action_time', 'user_id',
#        'visit_first_action_time', 'visit_goal_converted',
#        'visitor_days_since_order', 'visitor_returning', 'visitor_count_visits',
#        'visit_entry_idaction_name', 'visit_entry_idaction_url',
#        'visit_exit_idaction_name', 'visit_exit_idaction_url',
#        'visit_total_actions', 'visit_total_interactions',
#        'visit_total_searches', 'referer_keyword', 'referer_name',
#        'referer_type', 'location_browser_lang', 'config_browser_engine',
#        'config_browser_name', 'config_browser_version', 'config_device_brand',
#        'config_device_model', 'config_os', 'config_os_version',
#        'visit_total_events', 'visitor_localtime', 'config_resolution',
#        'config_cookie', 'config_director', 'config_flash', 'config_gears',
#        'config_java', 'config_pdf', 'config_quicktime', 'config_realplayer',
#        'config_silverlight', 'config_windowsmedia', 'visit_total_time',
# ...

# %%
df = df.drop(['idvisit', 'idsite','visit_first_action_time'],axis=1)

# %%
df.head()
# Out:
#   visit_last_action_time  user_id  visit_goal_converted  \
# 0       26-06-2019 12:18       25                     0
# 1       26-06-2019 12:18       31                     0
# 2       26-06-2019 02:19       31                     0
# 3       26-06-2019 02:50       31                     0
# 4       26-06-2019 03:38       31                     0
#
#    visitor_days_since_order  visitor_returning  visitor_count_visits  \
# 0                         0                  2                     1
# 1                         0                  0                     1
# 2                         0                  0                     1
# 3                         0                  1                     1
# 4                         0                  1                     1
#
#    visit_entry_idaction_name visit_entry_idaction_url  \
# 0                        133                      134
# 1                        286                      287
# ...

# %%
df[['dmy','time']] = df.visit_last_action_time.str.split(" ",expand=True)

# %%
df.head()
# Out:
#   visit_last_action_time  user_id  visit_goal_converted  \
# 0       26-06-2019 12:18       25                     0
# 1       26-06-2019 12:18       31                     0
# 2       26-06-2019 02:19       31                     0
# 3       26-06-2019 02:50       31                     0
# 4       26-06-2019 03:38       31                     0
#
#    visitor_days_since_order  visitor_returning  visitor_count_visits  \
# 0                         0                  2                     1
# 1                         0                  0                     1
# 2                         0                  0                     1
# 3                         0                  1                     1
# 4                         0                  1                     1
#
#    visit_entry_idaction_name visit_entry_idaction_url  \
# 0                        133                      134
# 1                        286                      287
# ...

# %%
df = df.drop(["visit_last_action_time"],axis=1)

# %%
df.head(5)
# Out:
#    user_id  visit_goal_converted  visitor_days_since_order  visitor_returning  \
# 0       25                     0                         0                  2
# 1       31                     0                         0                  0
# 2       31                     0                         0                  0
# 3       31                     0                         0                  1
# 4       31                     0                         0                  1
#
#    visitor_count_visits  visit_entry_idaction_name visit_entry_idaction_url  \
# 0                     1                        133                      134
# 1                     1                        286                      287
# 2                     1                        288                      289
# 3                     1                          0                      NaN
# 4                     1                        294                      207
#
# ...

# %%
df[['date','month','year']] = df.dmy.str.split("-",expand=True)

# %%
df = df.drop(['dmy'],axis=1)

# %%
df.head(5)
# Out:
#    user_id  visit_goal_converted  visitor_days_since_order  visitor_returning  \
# 0       25                     0                         0                  2
# 1       31                     0                         0                  0
# 2       31                     0                         0                  0
# 3       31                     0                         0                  1
# 4       31                     0                         0                  1
#
#    visitor_count_visits  visit_entry_idaction_name visit_entry_idaction_url  \
# 0                     1                        133                      134
# 1                     1                        286                      287
# 2                     1                        288                      289
# 3                     1                          0                      NaN
# 4                     1                        294                      207
#
# ...

# %%
df['min'] = df['time'].apply(lambda x: x.split(':')[0])
df['sec'] = df['time'].apply(lambda x: x.split(':')[1])

# %%
df[['min', 'sec']].head()
# Out:
#   min sec
# 0  12  18
# 1  12  18
# 2  02  19
# 3  02  50
# 4  03  38

# %%
df.drop(['time'], inplace=True, axis=1)

# %%
df.head()
# Out:
#    user_id  visit_goal_converted  visitor_days_since_order  visitor_returning  \
# 0       25                     0                         0                  2
# 1       31                     0                         0                  0
# 2       31                     0                         0                  0
# 3       31                     0                         0                  1
# 4       31                     0                         0                  1
#
#    visitor_count_visits  visit_entry_idaction_name visit_entry_idaction_url  \
# 0                     1                        133                      134
# 1                     1                        286                      287
# 2                     1                        288                      289
# 3                     1                          0                      NaN
# 4                     1                        294                      207
#
# ...

# %%
df['visit_entry_idaction_url'] = df['visit_entry_idaction_url'].fillna(0)

# %%
df
# Out:
#      user_id  visit_goal_converted  visitor_days_since_order  \
# 0         25                     0                         0
# 1         31                     0                         0
# 2         31                     0                         0
# 3         31                     0                         0
# 4         31                     0                         0
# 5         31                     0                         0
# 6         31                     0                         0
# 7         45                     0                         0
# 8         45                     1                         0
# 9         45                     0                         0
# 10         9                     0                         0
# 11         9                     1                         0
# 12         9                     1                         0
# 13         9                     0                         0
# ...

# %%
df.isnull().sum()
# Out:
# user_id                       0
# visit_goal_converted          0
# visitor_days_since_order      0
# visitor_returning             0
# visitor_count_visits          0
# visit_entry_idaction_name     0
# visit_entry_idaction_url      0
# visit_exit_idaction_name      0
# visit_exit_idaction_url       5
# visit_total_actions           0
# visit_total_interactions      0
# visit_total_searches          0
# referer_keyword               0
# referer_name                  0
# referer_type                  0
# location_browser_lang         0
# config_browser_engine         0
# config_browser_name           0
# config_browser_version       11
# config_device_brand           0
# config_device_model           0
# config_os                     0
# config_os_version             0
# visit_total_events            0
# visitor_localtime             0
# config_resolution             0
# config_cookie                 0
# config_director               0
# config_flash                  0
# ...

# %%
df['config_browser_version']  = df['config_browser_version'].fillna(0)

# %%
df.isnull().sum()
# Out:
# user_id                      0
# visit_goal_converted         0
# visitor_days_since_order     0
# visitor_returning            0
# visitor_count_visits         0
# visit_entry_idaction_name    0
# visit_entry_idaction_url     0
# visit_exit_idaction_name     0
# visit_exit_idaction_url      5
# visit_total_actions          0
# visit_total_interactions     0
# visit_total_searches         0
# referer_keyword              0
# referer_name                 0
# referer_type                 0
# location_browser_lang        0
# config_browser_engine        0
# config_browser_name          0
# config_browser_version       0
# config_device_brand          0
# config_device_model          0
# config_os                    0
# config_os_version            0
# visit_total_events           0
# visitor_localtime            0
# config_resolution            0
# config_cookie                0
# config_director              0
# config_flash                 0
# config_gears                 0
# ...

# %%
df['visit_exit_idaction_url']  = df['visit_exit_idaction_url'].fillna(0)

# %%
df.isnull().sum()
# Out:
# user_id                      0
# visit_goal_converted         0
# visitor_days_since_order     0
# visitor_returning            0
# visitor_count_visits         0
# visit_entry_idaction_name    0
# visit_entry_idaction_url     0
# visit_exit_idaction_name     0
# visit_exit_idaction_url      0
# visit_total_actions          0
# visit_total_interactions     0
# visit_total_searches         0
# referer_keyword              0
# referer_name                 0
# referer_type                 0
# location_browser_lang        0
# config_browser_engine        0
# config_browser_name          0
# config_browser_version       0
# config_device_brand          0
# config_device_model          0
# config_os                    0
# config_os_version            0
# visit_total_events           0
# visitor_localtime            0
# config_resolution            0
# config_cookie                0
# config_director              0
# config_flash                 0
# config_gears                 0
# ...

# %%
df.head()
# Out:
#    user_id  visit_goal_converted  visitor_days_since_order  visitor_returning  \
# 0       25                     0                         0                  2
# 1       31                     0                         0                  0
# 2       31                     0                         0                  0
# 3       31                     0                         0                  1
# 4       31                     0                         0                  1
#
#    visitor_count_visits  visit_entry_idaction_name visit_entry_idaction_url  \
# 0                     1                        133                      134
# 1                     1                        286                      287
# 2                     1                        288                      289
# 3                     1                          0                        0
# 4                     1                        294                      207
#
# ...

# %%
df["visitor_localtime"] = df["visitor_localtime"].str.replace(":", " ")

# %%
df.head()
# Out:
#    user_id  visit_goal_converted  visitor_days_since_order  visitor_returning  \
# 0       25                     0                         0                  2
# 1       31                     0                         0                  0
# 2       31                     0                         0                  0
# 3       31                     0                         0                  1
# 4       31                     0                         0                  1
#
#    visitor_count_visits  visit_entry_idaction_name visit_entry_idaction_url  \
# 0                     1                        133                      134
# 1                     1                        286                      287
# 2                     1                        288                      289
# 3                     1                          0                        0
# 4                     1                        294                      207
#
# ...

# %%
df[['visitor_localtime_hour','visitor_localtime_min','visitor_localtime_sec']] = df.visitor_localtime.str.split(" ",expand=True)

# %%
df = df.drop(['visitor_localtime'],axis=1)

# %%
df.head()
# Out:
#    user_id  visit_goal_converted  visitor_days_since_order  visitor_returning  \
# 0       25                     0                         0                  2
# 1       31                     0                         0                  0
# 2       31                     0                         0                  0
# 3       31                     0                         0                  1
# 4       31                     0                         0                  1
#
#    visitor_count_visits  visit_entry_idaction_name visit_entry_idaction_url  \
# 0                     1                        133                      134
# 1                     1                        286                      287
# 2                     1                        288                      289
# 3                     1                          0                        0
# 4                     1                        294                      207
#
# ...

# %%
df.to_csv("hey.csv",index=False)

# %%
df.shape
# Out:
# (345, 52)
